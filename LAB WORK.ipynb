# %%
from os import name

from SEQUENCE import age


# Parent class
class person:
    def__init__(self,name,age):
       self.name=name
       self.age=age
    def display__info(self):
        print("name:",self.name)
        print("age:",self.age)
    #child class:student
    class student(person):
        def __init__(self,name,age,student__id):
            super().__init__(name,age)
            self.student__id=student__id
        def enroll__course(self ):
            print(self.name,"has enrolled in a course")
        # overridden method
        def dispay __info(self):
           super().display__info()
           print("student id:",self.student__id)
        #child class:lecturer
        class lecturer(person):
            def __init__(self,name,age,employee__id):
                super().__init__(name,age)
                self.employee__id=employee__id
            def teach__course(self):
                print(self.name,"is teaching a course.")
        #create objects
        student=student("Prosper",20,"STOO1")
        lecturer=lecturer("mary",40,"EM101")
        #demonstrate students
        print("student details")
        student .display__info()
        student.enroll__course()
        print()
        #demonstrate lecturer
        print("lecturer details")
        lecturer.display__info()
        print("employee id:",lecturer.employee__id)
        lecturer.teach__course()
